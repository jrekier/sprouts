# %%
<<"../../spectral.m"
<<"../../fennec.m"

# %%
\[ScriptCapitalL] = {\[Phi][0, 0]''[r] + 
     2/r \[Phi][0, 0]'[r] - (0 (0 + 1))/
      r^2 \[Phi][0, 0][r] == -\[Lambda] \[Phi][0, 0][r]};

# %%
\[ScriptCapitalB] = {\[Phi][0, 0][1] == 0};
\[ScriptCapitalV] = {\[Phi][0, 0]};

# %%
A = FennecFun[
  Join[\[ScriptCapitalL], \[ScriptCapitalB]], \[ScriptCapitalV], {r, 
   0, 1}, 20, eigenvalue -> \[Lambda]]
# Out:
# {SparseArray[<27>, {10, 10}], SparseArray[<33>, {10, 10}]}

# %%
Block[
 {nr = Fennec`nr, n = Fennec`nColTotal, 
  nbc = Length@Fennec`rbc[[1]], \[Delta]},
 \[Delta] = n - nbc;
 p = SparseArray@
   IdentityMatrix[n][[
    Riffle[Range[\[Delta]], Range[\[Delta] + 1, n], {1, n, nr/2}]]]
 ]
# Out:
# SparseArray[<10>, {10, 10}]

# %%
GraphicsRow[{MatrixPlot[p.A[[1]],ImageSize->Small],MatrixPlot[p.A[[2]],ImageSize->Small]}]
# Out:
# -Graphics-

# %%
Sort@Eigenvalues[{p.A[[1]], -p.A[[2]]}] // Sqrt
# Out:
# {3.14159, 6.28319, 9.42478, 12.5666, 15.7017, 19.0347, 23.2366, 33.2368, 53.3315,
#
# >   Infinity}

# %%
(*analytical solutions *)
Table[BesselJZero[1/2, i], {i, 1, 20}] // N
# Out:
# {3.14159, 6.28319, 9.42478, 12.5664, 15.708, 18.8496, 21.9911, 25.1327, 28.2743,
#
# >   31.4159, 34.5575, 37.6991, 40.8407, 43.9823, 47.1239, 50.2655, 53.4071, 56.5487,
#
# >   59.6903, 62.8319}
